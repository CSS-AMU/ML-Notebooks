# %%
import os

# %%
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  '.jovianrc',
#  'Titanic Shipwreck Analysis.ipynb',
#  'train.csv']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\zikra\\Data Analysis'

# %%
# !pip install pandas
# Out:
# Active code page: 1252
# ...

# %%
import pandas as pd

# %%
data_df1 = pd.read_csv('train.csv')

# %%
data_df = data_df1.copy()

# %%
data_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(data_df)
# Out:
# pandas.core.frame.DataFrame

# %%
data_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
type(data_df.Fare)
# Out:
# pandas.core.series.Series

# %%
# replacing the nan values of age column with median value
data_df['Age'].fillna(value = data_df['Age'].median() , inplace = True)

# %%
data_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
#Dropping the column 'Cabin' as it contains 687 NaN values out of 891
data = data_df.drop(['Cabin'], axis = 1)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
index = data.index

# %%
#found that column 'Ticket' has non unique values
len(data.Ticket.unique())
# Out:
# 681

# %%
#finding tickets per unique ticket
data['Ticket'].value_counts()
# Out:
# CA. 2343              7
# 1601                  7
# 347082                7
# 347088                6
# CA 2144               6
#                      ..
# S.P. 3464             1
# 2693                  1
# SOTON/O.Q. 3101312    1
# STON/O2. 3101283      1
# PC 17474              1
# Name: Ticket, Length: 681, dtype: int64

# %%
#define a dictionary which has unique value of 'Tickets' as keys and no.of tickets per unique ticket as values
ticketdict = data['Ticket'].value_counts().to_dict()

#defining new fare by dividing the old fare values by no.of tickets per unique ticket.
for i in range(len(data.Fare)):
  a = data.Fare[i]
  new_fare = data.Fare[i]/(ticketdict[data.Ticket[i]])
  data['Fare'] = data['Fare'].replace([data.Fare[i]],new_fare)
    
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594    7.854877
# std      0.806057   15.385873
# min      0.000000    0.000000
# 25%      0.000000    0.251563
# 50%      0.000000    3.318750
# 75%      0.000000    7.895800
# max      6.000000  221.779200

# %%
#Removing an outlier
index_names = data[data['Fare'] == max(data.Fare)].index
data.drop(index_names, inplace = True)
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    445.984252    0.384702    2.311586   29.365771    0.524184
# std     257.618690    0.486799    0.834700   13.034028    1.103705
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     669.000000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  889.000000  889.000000
# mean     0.380202    7.385170
# std      0.805032   11.781334
# min      0.000000    0.000000
# 25%      0.000000    0.251563
# 50%      0.000000    3.318750
# 75%      0.000000    7.895800
# max      6.000000   81.858300

# %%
# !pip install matplotlib seaborn --upgrade --quiet
# Out:
# Active code page: 1252

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(8,4))

# %%
sns.countplot(x=data['Sex'], hue=data['Survived']);

# %% [markdown]
# The above graph shows that besides being less in numbers than males ,more females had survived

# %%
sns.countplot(x=data['Pclass'], hue=data['Sex']);

# %% [markdown]
# the graph shows sex ratio among all the passenger classes.

# %%
sns.countplot(x=data['Pclass'], hue=data['Survived']);

# %% [markdown]
# the graph shows the survival rate among all the passenger classes

# %%
sns.barplot('Pclass','Fare',hue = 'Embarked', data = data);
# Out:
# C:\Users\zikra\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# the above graph shows the distribution of Fare according to the respective ports of Embarkments against all the passenger classes

# %%
sns.countplot(x=data['Pclass'], hue=data['Embarked']);

# %% [markdown]
# the graph shows the strength of passengers according to their port of Embarkment in respective Passenger Classes

# %%
d1 = data[data.Pclass == 1]
sns.barplot('Embarked', 'Fare', data = d1);
# Out:
# C:\Users\zikra\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
d2 = data[data.Pclass == 2]
sns.barplot('Embarked', 'Fare', data = d2);
# Out:
# C:\Users\zikra\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
d3 = data[data.Pclass == 3]
sns.barplot('Embarked', 'Fare', data = d3);
# Out:
# C:\Users\zikra\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data[data.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Embarked
# 61   female  38.0      0      0  113572  20.0      NaN
# 829  female  62.0      0      0  113572  20.0      NaN

# %%
d1[d1.Fare == max(d1.Fare)]
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex  Age  \
# 445          446         1       1  Dodge, Master. Washington  male  4.0
#
#      SibSp  Parch Ticket     Fare Embarked
# 445      0      2  33638  81.8583        S

# %%
data_df1[data_df1.Ticket == '347082']
# Out:
#      PassengerId  Survived  Pclass  \
# 13            14         0       3
# 119          120         0       3
# 541          542         0       3
# 542          543         0       3
# 610          611         0       3
# 813          814         0       3
# 850          851         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 541               Andersson, Miss. Ingeborg Constanzia  female   9.0      4
# 542                  Andersson, Miss. Sigrid Elisabeth  female  11.0      4
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.0      1
# 813                 Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 850            Andersson, Master. Sigvard Harald Elias    male   4.0      4
#
#      Parch  Ticket    Fare Cabin Embarked
# ...

# %%
data[data.Fare == max(data.Fare)]
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex  Age  \
# 445          446         1       1  Dodge, Master. Washington  male  4.0
#
#      SibSp  Parch Ticket     Fare Embarked
# 445      0      2  33638  81.8583        S
